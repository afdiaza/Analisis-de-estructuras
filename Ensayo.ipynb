# %% [markdown]
# # Hallemos la matriz local

# %% [markdown]
# Hola Daniela

# %%
A=20000
E=200
L=100

# %% [markdown]
# Imprimir área

# %%
print(A)
# Out:
# 20000

# %%
from skimage import io


image=io.imread("Matriz_cercha_plana.jpg")/255.0 # imread lee las imagenes con los pixeles codificados como enteros 
# en el rango 0-255. Por eso la convertimos a flotante y en el rango 0-1
plt.imshow(image,vmin=0,vmax=1)
